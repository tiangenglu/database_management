# %%
import boto3
import io
import pandas as pd
import getpass

# %% [markdown]
# # Log in S3

# %%
my_aws_access_key_id = '{0}'.format(getpass.getpass('aws_access_key_id: '))
# Out:
# aws_access_key_id: ········

# %%
my_aws_secret_access_key = '{0}'.format(getpass.getpass('aws_secret_access_key: '))
# Out:
# aws_secret_access_key: ········

# %% [markdown]
# # Connect to S3

# %%
my_bucket = '{0}'.format(getpass.getpass('bucket_name: '))
# Out:
# bucket_name: ········

# %%
session = boto3.Session(profile_name = None,
                       region_name = 'us-east-2')

# %%
conn = session.client('s3',
                     aws_access_key_id = my_aws_access_key_id,
                     aws_secret_access_key = my_aws_secret_access_key)

# %%
files_content = conn.list_objects(Bucket = my_bucket)['Contents']

# %%
file_names = [file['Key'] for file in files_content]

# %%
# how many files?
print(len(file_names))
# Out:
# 41

# %% [markdown]
# # Upload `.txt` to Bucket

# %%
PA_York_detail = open("detail.txt", "r", encoding='utf-8')

# %%
conn.put_object(Body = PA_York_detail.read(),
               Bucket = my_bucket,
               Key = 'detail.txt')
# Out:
# {'ResponseMetadata': {'RequestId': 'B6ME21GRH5DDPA2G',
#   'HostId': '7kBc3El3Q9V/Lluawsx+Rz72PnsEeG13neQqNkK6C27ts/Ln98JEsM6oxfl+/cdvyG3R4ydCueY=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': '7kBc3El3Q9V/Lluawsx+Rz72PnsEeG13neQqNkK6C27ts/Ln98JEsM6oxfl+/cdvyG3R4ydCueY=',
#    'x-amz-request-id': 'B6ME21GRH5DDPA2G',
#    'date': 'Thu, 20 Feb 2025 03:40:08 GMT',
#    'x-amz-server-side-encryption': 'AES256',
#    'etag': '"e5853cb6a30c3469052706b0f8e04ae4"',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"e5853cb6a30c3469052706b0f8e04ae4"',
#  'ServerSideEncryption': 'AES256'}

# %% [markdown]
# ![image.png](attachment:image.png)
